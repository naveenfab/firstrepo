# %% [markdown]
#  #Project Work
# # The Ecommerce Fashion Industry

# %% [markdown]
# ### Aiming at fashion industry to keep up with the trends and helps to grow its online fashion business.
#
# <img src="fashion.png" style="max-width:800px">
#
# #### Contents of the Notebook:
# <font color=blue>
#     <span style="font-family:Arial">1. Business Understanding </span>
#             <span style="font-family:Arial"><ul><li> Description </li></ul></span>
#             <span style="font-family:Arial"><ul><li> Objective </li></ul></span>
#     <span style="font-family:Arial">2. Data Understanding </span>
#             <span style="font-family:Arial"><ul><li> Import Libraries </li></ul></span>
#             <span style="font-family:Arial"><ul><li> Load Data </li></ul></span>
#             <span style="font-family:Arial"><ul><li> Statistical summaries and visualisations </li></ul></span>
#     <span style="font-family:Arial">3. Data Preparation </span>
#             <span style="font-family:Arial"><ul><li> Missing values imputation </li></ul></span>
#     <span style="font-family:Arial">4. Exploratory Data Analysis </span>
#             <span style="font-family:Arial"><ul><li> Features Exploration </li></ul></span>
#     <span style="font-family:Arial">5. Data Splitting </span>
#             <span style="font-family:Arial"><ul><li> Train test split </li></ul></span>
#     <span style="font-family:Arial">6. Modeling </span>
#             <span style="font-family:Arial"><ul><li> Model1: Modeling with the linear model and tree based model technique with Standard Scaler. </li></ul></span>
#             <span style="font-family:Arial"><ul><li> Model2: Modeling with the linear model and tree based model technique by adjusting outliers & Standard Scaler. </li></ul></span>
#             <span style="font-family:Arial"><ul><li> Model3: Modeling with the linear model and tree based model technique by adjusting outliers & Log Transformation. </li></ul></span>
#     <span style="font-family:Arial">7. Finalizing Model Choice </span>
#             <span style="font-family:Arial"><ul><li> Model performance </li></ul></span>
#             <span style="font-family:Arial"><ul><li> Feature importance </li></ul></span>
#     <span style="font-family:Arial">8. Deployment </span><br>
#     <span style="font-family:Arial">9. Conclusion & Recommendation </span><br>
# </font>
#
# ***
# ---
# # 1. Business Understanding
#
# # 1.1 The Data
#
# ## What is Ecommerce?
# <span style='color:green'>
# Ecommerce, also known as electronic commerce or internet commerce, refers to the buying and selling of goods or services using the internet, and the transfer of money and data to execute these transactions. Ecommerce is often used to refer to the sale of physical products online, but it can also describe any kind of commercial transaction that is facilitated through the internet.
# </span>
#
# ### Types of Ecommerce Models
#
# |       |       |
# | :---: | :---: |
# |<span style= 'background:yellow'>1. Business to Consumer (B2C)</span>| When a business sells a good or service to an individual consumer (e.g. You buy a pair of shoes from an online retailer).|
# |<span style= 'background:yellow'>2. Business to Business (B2B)</span>| When a business sells a good or service to another business (e.g. A business sells software-as-a-service for other businesses to use)|
# |<span style= 'background:yellow'>3. Consumer to Consumer (C2C)</span>| When a consumer sells a good or service to another consumer (e.g. You sell your old furniture on eBay to another consumer).|
# |<span style= 'background:yellow'>4. Consumer to Business (C2B)</span>|When a consumer sells their own products or services to a business or organization (e.g. An influencer offers exposure to their online audience in exchange for a fee, or a photographer licenses their photo for a business to use).|
# |<span style= 'background:yellow'>5. Direct to Consumer (D2C)</span>|D2C means that a brand is selling directly to their end customer without going through a retailer, distributor, or wholesaler. Subscriptions are a popular D2C item, and social selling via platforms like InstaGram, Pinterest, TikTok, Facebook, SnapChat, etc.|
#
# ### The Importance of eCommerce
#
# |       |       |
# | :---: | :---: |
# |1. eCommerce Helps You Reduce Your Costs| To have an online store it is not necessary that you have all your products presented in a physical space. In fact, there are different companies that operate online where they only show all their inventory through their electronic commerce.|
# |2. eCommerce Helps Businesses Go Global| This fact allows you to put your products for sale anywhere in the world.If you are running a physical store, it will be limited by the geographical area that you can service.|
# |3. eCommerce Can Be Done With Fewer Overheads & Fewer Risk| The retailer or the online business owner doesn’t have to take into consideration the high expenses of shop rental, hiring a salesperson to woo the customer, utility bills, security measures, etc. This, in turn, will enable you to sell your products at competitive prices. Also, having an online store enables you to enjoy increased profitability with less risk.|
# |4. eCommerce Can Broaden Your Brand & Expand Your Business|Having an eCommerce store can be used to broaden your range of products/services for sale, expanding your business, bringing you more custom, and diversifying your sales. It’s the ideal way to take your brand from a traditional brick & mortar store to an innovative, well-loved one.|
# |5. eCommerce Offers Better Marketing Opportunities| Email marketing, Increase sales and inspire your customers, On-the-fly relevance, Personalise your newsletters, Include recommendations in your transactional emails|
# |6. Your Online Store Will Stay Open 24/7, 365| eCommerce retailers can enjoy is store timings are now 24/7/365 as the eCommerce stores are open 24 hours a day, 7 days a week, compared to the regular stores.|
# |7. Personalize Your Shopping Experience| If there is one of the clear advantages of having an online store, that is to be able to know (and monitor) what your consumer does.|
# |8. Easily Receive Feedback on Products| Customer reviews, Ask for feedback, and take advantage of it, Fashion shoppers trust reviews, How to deal with negative reviews|
# |9. Increase in Sales| Everything seen above is focused on one thing: being able to increase your sales.|
# |10. Focus on the customer experience| Offer easy and smooth deliveries/returns, Customer service, Offer different payment methods|
# |11. Optimise your eCommerce SEO(Search Engine Optimization)| Find the right keyword, Search volume,  to see if that particular keyword is relevant. It must be relevant to the specific product being sold.|
# |12. Use artificial intelligence to improve product recommendations| Inspire with the best-selling products, Benefit from visitors with similar tastes, Recommendations based on favourites, Increase the shopping cart value|
# |13. Influencer marketing| Increase conversions with influencer marketing,  Use unique links for each influencer and discounts codes for limited offers.|
# |14. Sustainability| Sustainable transports, Sustainable packaging|
# |15. Ecommerce site search| Autocomplete, Content Search, Image search|
# |16. Do marketing through video| Product close-up video, Product overview video, Customer testimonial video|
# |17. Social commerce| Combining eCommerce with social media, Social commerce growth|
# |18. **Benefits of Fashion Mobile App Stores to Customers**|  Convenience to Shoppers,  Offers & Discounts, Constant Reminders, Fere Fashion Consultant, Useful Filters |
# |19. **Fashion Brands Prefer Their Own Fashion eCommerce Mobile App**| No Competition, Data Analytics, Audience Feedback, Target Customers, Revenue Growth-To gain trust in your customers is the ultimate achievement of any eCommerce application, Special Offers and Discounts, Marketing|
# |20. **Why e-Commerce Websites Importance**| Customer Comfort,  Building Credibility with Online Marketing,  High Conversion Rate = More Sales, It Gives You a 24/7 Runway, It Opens Up More Selling Opportunities, It Saves You Money|
#
# <img src="246385.png" style="max-width:800px">
#
# # 1.2 Business Problem
# This dataset includes description of an Ecommerce company based in London sells clothing online but they also have in-store style and clothing advice sessions. Customers come in to the store, have sessions/meetings with a personal stylist, then they can go home and order either on a mobile app or website for the clothes they want. The company is trying to decide whether to focus their efforts on their mobile app experience or their website. They've asked to help them figure it out.
#
# Summary:We worked with the Ecommerce company and the dataset name is Ecommerce.csv. It has Customer info, such as Customer ID, Avg Session length, Time on App, Time on Website, Length of MemberShip, Yealy amount spent.
#
# Attribute Information:
#
# 1. Customer ID: A unique identification number given to every Customer.
# 2. Avg Session length: Customers come in to the store, have sessions/meetings with a personal stylist.
# 3. Time on App: Time spent by customer on company mobile app.
# 4. Time on Website: Time spent by customer on website.
# 5. Length of MemberShip:The number of years/months in a membership term by customer.
# 6. Yealy amount spent:Amount yearly spent by customer in an ecommerce shopping with the company.
#
# ## Lets Discuss on the Feature Given to us:
#
# |        |          |
# | :---: | :---: |
# |**Time on App**|Mobile apps are noticed playing an important role in building relationships between businesses and customers.Using a mobile eCommerce platform, the brands find an easy way to connect with their customers as most of the consumers spend lots of hours on their mobile. According to App Annie, time spent by US consumers in shopping apps and increasing digital sales had a strong positive correlation.On average, people spend 3 hours and 40 minutes using their mobile devices each day.25% of people open a single app between 11 and 20 times each day.The usage of mobile shopping apps is 48% higher than average. This is a great opportunity for any business that sells products and services online.As long as you’re able to get people to install your app on their mobile devices, those downloads will ultimately translate to dollars. The more users you have, the more money you’ll make.Mobile app usage is rising in popularity worldwide, which is translating to revenue growth all over the world.|
# |**Time on Website**|Website Traffic metric helps to ecommerce companies understand the popularity of a website. Increasing website traffic is often a goal for ecommerce websites. The conversion rate is the percentage of users who take a desired action. For e-commerce, one of the most important conversion rates is the percentage of website visitors who buy something on the site.Time To Purchase metric tells you approximately how long it took for visitors to your site to change into actual customers. While some people may visit your site and immediately make a purchase, others may visit two, three, or even more than ten times before they decide to buy from you.Average Transaction Value  is the average dollar amount that a consumer spends with you, within a single transaction.The ATV is very important when evaluating the total success of a business.|
# |**Length of MemberShip**|Lenght of Membership is the  customer lifetime value (CLV) calculation is time spent as a customer – commonly referred to as the customer’s lifetime. customer’s lifetime in a marketing context, we are considering the average length of time a consumer is a customer of the brand or a firm.CLV is a measurement of how valuable a customer is to your company, not just on a purchase-by-purchase basis but across the whole relationship.|
# |**Yealy amount spent**|Yearly spent done by customer is the yearly revenue generated by company. The total amount of money that is being received by the company after trading its products or service with its customers.|
#
#
# * **Conversion rates- Understanding your conversion rates is a key component to running a successful ecommerce business.How many people are navigating to your website each day? What percentage of those visitors are converting?, If those numbers are too low, you’ll have to identify what’s wrong with your conversion funnel.**
#
# <img src="image4-1.png" style="max-width:800px">
# <img src="emizen_higher_conversion_rate_img2.png" style="max-width:500px">
#
#
# ## 1.3 Business Objective
# ---
# ---
# **Company Business Problem:The company is trying to decide whether to focus their efforts on their mobile app experience or their website.Interpret which variables are contributing towards the more annual income prediction.**
#
# **Objective: The objective of the analysis is to predict Feature Importance. Feature importance refers to techniques that assign a score to input features based on how useful they are at predicting a target variable. Our overall goal is to use the Ecommerce dataset shown below to develop a machine learning model that attempts to predict which variables is contributing towards the more annual income, so that company can maintain its budget by investing more in that, to gain more revenue and its helps to grom its online business.**
#
# ---
# ---
# ***

# %% [markdown]
# # 2. Data Understanding
#
# ## 2.1 Import Libraries

# %%
# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Handle table-like data and matrices
import numpy as np
import pandas as pd


# Modelling Algorithms
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.svm import SVR

# Modelling Helpers
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Visualisation
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
from matplotlib import pyplot
import seaborn as sns

# Configure visualisations
# %matplotlib inline

# %%
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# ## 2.2 Load Data

# %%
dataset= pd.read_csv('Ecommerce.csv')
dataset
# Out:
#      Customer ID  Avg Session length  Time on App  Time on Website  \
# 0              1           32.538350    12.028846        35.850540
# 1              2           34.206718    12.226851        37.246443
# 2              3           31.535240    11.814341        36.610697
# 3              4           32.199577    11.295163        37.425695
# 4              5           33.570137    13.500972        36.856165
# ..           ...                 ...          ...              ...
# 618          619           31.941434    11.158640        36.846959
# 619          620           33.446133    12.374820        37.592235
# 620          621           32.967749    11.392061        36.916664
# 621          622           33.469949    11.930872        37.744155
# 622          623           33.443393    12.978933        37.311979
#
#      Length of MemberShip  Yealy amount spent
# 0                3.648854          576.098273
# 1                1.987536          460.784955
# ...

# %% [markdown]
# **Creating copy of dataset so that we can use dataset one with outliers and other without outliers.**

# %%
df= dataset.copy()

# %% [markdown]
# ## 2.3 Statistical summaries and visualisations

# %%
df.head()
# Out:
#    Customer ID  Avg Session length  Time on App  Time on Website  \
# 0            1           32.538350    12.028846        35.850540
# 1            2           34.206718    12.226851        37.246443
# 2            3           31.535240    11.814341        36.610697
# 3            4           32.199577    11.295163        37.425695
# 4            5           33.570137    13.500972        36.856165
#
#    Length of MemberShip  Yealy amount spent
# 0              3.648854          576.098273
# 1              1.987536          460.784955
# 2              3.351191          349.739791
# 3              5.234337          547.709921
# 4              3.938603          487.055641

# %%
# Checking the data type
df.dtypes
# Out:
# Customer ID               int64
# Avg Session length      float64
# Time on App             float64
# Time on Website         float64
# Length of MemberShip    float64
# Yealy amount spent      float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 623 entries, 0 to 622
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Customer ID           623 non-null    int64
#  1   Avg Session length    623 non-null    float64
#  2   Time on App           623 non-null    float64
#  3   Time on Website       623 non-null    float64
#  4   Length of MemberShip  623 non-null    float64
#  5   Yealy amount spent    623 non-null    float64
# dtypes: float64(5), int64(1)
# memory usage: 29.3 KB

# %%
df.shape
# Out:
# (623, 6)

# %% [markdown]
# **VARIABLE DESCRIPTIONS:**
#
# We've got a sense of our variables, their class type, and the first few observations of each. We know we're working with 623 observations of 6 variables. Here's what we've got to deal with:
# Attribute Information:
#
# 1. Customer ID: A unique identification number given to every Customer.
# 2. Avg Session length: Customers come in to the store, have sessions/meetings with a personal stylist.
# 3. Time on App: Time spent by customer on company mobile app.
# 4. Time on Website: Time spent by customer on website.
# 5. Length of MemberShip:The number of years/months in a membership term by customer.
# 6. Yealy amount spent:Amount yearly spent by customer in an ecommerce shopping with the company.
#
# ## 2.3.1 Next have a look at some key information about the variables

# %%
df.describe().T
# Out:
#                       count        mean         std         min         25%  \
# Customer ID           623.0  312.000000  179.988889    1.000000  156.500000
# Avg Session length    623.0   33.039429    0.949071   29.972300   32.375680
# Time on App           623.0   12.001459    0.996609    9.273248   11.334163
# Time on Website       623.0   37.079018    0.991753   33.751071   36.376725
# Length of MemberShip  623.0    3.514850    0.948063    0.891398    2.906558
# Yealy amount spent    623.0  499.600023   80.032965  256.670000  447.665160
#
#                              50%         75%         max
# Customer ID           312.000000  467.500000  623.000000
# Avg Session length     33.044399   33.700947   35.744415
# Time on App            11.998823   12.647695   15.138317
# Time on Website        37.113631   37.773880   40.808388
# Length of MemberShip    3.504771    4.140305    6.553916
# Yealy amount spent    498.806136  551.257208  775.337626

# %% [markdown]
# The minimum timing that a customer spend at the store is 30 min and the maximum is 35 min. The minimum average time spent on mobile app is 9 min and the maximum is 15 min, time spent on website mean is 37 min that is much more than that of App. The std shows that data are less despersed in relation to the mean. The max increase in yearly amount spent shows that the data is not normally distributed, there is skewness in the dataset.

# %%
# Finding the relations between the variables.
plt.figure(figsize=(14,5))
c= df.corr()
sns.heatmap(c,cmap='viridis',annot=True,fmt='.2f')
c
# Out:
#                       Customer ID  Avg Session length  Time on App  \
# Customer ID              1.000000           -0.036917    -0.001085
# Avg Session length      -0.036917            1.000000    -0.001234
# Time on App             -0.001085           -0.001234     1.000000
# Time on Website          0.009227            0.050231     0.040029
# Length of MemberShip     0.052600           -0.010919     0.029839
# Yealy amount spent      -0.075175           -0.042764    -0.012348
#
#                       Time on Website  Length of MemberShip  \
# Customer ID                  0.009227              0.052600
# Avg Session length           0.050231             -0.010919
# Time on App                  0.040029              0.029839
# Time on Website              1.000000              0.036788
# Length of MemberShip         0.036788              1.000000
# Yealy amount spent           0.084305             -0.030451
#
#                       Yealy amount spent
# ...

# %% [markdown]
# ### Inference from ‘r’ values and heat map
#
# * No 2 factors have strong linear relationships
# * Avg Session length, Time on App, Length of MemberShip are all negatively correlated with Yearly amount spent. Have moderate negative relationship.
# * Only Time on Website is positively related with all others variables.
# * 'Customer ID' is uniformaliy distributed and there is no correlation with other variable.

# %% [markdown]
# # 3. Data Preparation
# ## 3.1 Removing Irrelevant Column
#
# We will be removing the 'Customer ID' as doesn't make any sense with the company growth, its just an ID given to customer to locate in the company database. 'Customer ID' is an irrelevant columns to our dataset.Irrelevant features can decrease the accuracy of the model.

# %%
# Dropping irrelevant columns
df=df.drop('Customer ID', axis=1)
df.head()
# Out:
#    Avg Session length  Time on App  Time on Website  Length of MemberShip  \
# 0           32.538350    12.028846        35.850540              3.648854
# 1           34.206718    12.226851        37.246443              1.987536
# 2           31.535240    11.814341        36.610697              3.351191
# 3           32.199577    11.295163        37.425695              5.234337
# 4           33.570137    13.500972        36.856165              3.938603
#
#    Yealy amount spent
# 0          576.098273
# 1          460.784955
# 2          349.739791
# 3          547.709921
# 4          487.055641

# %% [markdown]
# # 3.2 Checking Missing, Duplicate

# %%
# Rows containing duplicate data
duplicate_rows_df = df[df.duplicated()]
print('number of duplicate rows:', duplicate_rows_df.shape)
# Out:
# number of duplicate rows: (0, 5)

# %%
# Finding the null values.
print(df.isnull().sum())
# Out:
# Avg Session length      0
# Time on App             0
# Time on Website         0
# Length of MemberShip    0
# Yealy amount spent      0
# dtype: int64

# %% [markdown]
# # 4. Exploratory Data Analysis
#
# ## 4.1 Feature Exploration on Distplot and Box Plot

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.title('Yealy amount spent')
sns.distplot(df['Yealy amount spent'])

plt.subplot(1,2,2)
plt.title('Yealy amount spent')
sns.boxplot(y=df['Yealy amount spent'])

plt.show()

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.title('Length of MemberShip')
sns.distplot(df['Length of MemberShip'])

plt.subplot(1,2,2)
plt.title('Length of MemberShip')
sns.boxplot(y=df['Length of MemberShip'])

plt.show()

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.title('Time on Website')
sns.distplot(df['Time on Website'])

plt.subplot(1,2,2)
plt.title('Time on Website')
sns.boxplot(y=df['Time on Website'])

plt.show()

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.title('Time on App')
sns.distplot(df['Time on App'])

plt.subplot(1,2,2)
plt.title('Time on App')
sns.boxplot(y=df['Time on App'])

plt.show()

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.title('Avg Session length')
sns.distplot(df['Avg Session length'])

plt.subplot(1,2,2)
plt.title('Avg Session length')
sns.boxplot(y=df['Avg Session length'])

plt.show()

# %% [markdown]
# ### Inference from above plot
# In the above Distplot and Box Plot visualization,
#
# (Left-distplot) all the variables are normally distributed, and there are little skewness in the dataset.
#
# For the (Right-Boxplot)   we can see 'Yealy amount spent ' & 'Length of MemberShip' consists lot of outliers present below the minimum and the maximum. These outliers value needs to be treated and there are several ways of treating them:

# %% [markdown]
# ## 4.2 Features Exploration on Histplot

# %%
figure, ax = plt.subplots(3, 2,figsize=(18,12))
sns.histplot(x=df['Avg Session length'],data=df,ax=ax[0,0]);
sns.histplot(x=df['Time on App'],data=df,ax=ax[0,1])
sns.histplot(x=df['Time on Website'],data=df,ax=ax[1,0])
sns.histplot(x=df['Length of MemberShip'],data=df,ax=ax[1,1])
sns.histplot(x=df['Yealy amount spent'],data=df,ax=ax[2,0])
plt.show()

# %% [markdown]
# # Checking the objective with the feature
#
# **As per our Company Business Problem or Business objective:**
#
# **The company is trying to decide whether to focus their efforts on their mobile app experience or their website.Interpret which variables are contributing towards the more annual income prediction.**
#
#    **So if we want to derive the company annual income that will depend on how much your customer spent in your company on your product that is how much customer purchases and leads to company income.**
#
#    **So, 'Yearly amount spent' by customer will be our target variable.**
#
# We will discuss more on this below by visualization.
#
# ## 4.3 Plot different features against one another (scatter), against frequency (histogram)

# %%
def scatter(x,fig):
    plt.subplot(5,2,fig)
    plt.scatter(df[x],df['Yealy amount spent']) 
    plt.title(x+' vs Yealy amount spent')
    plt.ylabel('Yealy amount spent')
    plt.xlabel(x)

# %%
#Below is the scatter plot of all the variables with comparison to our target variable(Yealy amount spent).
plt.figure(figsize=(10,20))

scatter('Avg Session length', 1)
scatter('Time on App', 2)
scatter('Time on Website', 3)
scatter('Length of MemberShip', 4)

plt.tight_layout()

# %% [markdown]
# **From scatter plots, we can see there is no positive nor negative linear relationships between the variable.**

# %% [markdown]
# ## 4.4 Feature Exploration on Pairplot

# %%
sns.pairplot(df);

# %% [markdown]
# ## Inference from Pair Plots
# * From scatter plots, we can see there is no positive no negative linear relationships between the variable.
# * For distribution all are normally distributed.

# %% [markdown]
#
#
# # 4.6 Plot different features against one another Barplot using bin.

# %%
print('Number of unique value',df['Time on App'].nunique())
print('Max value',df['Time on App'].max())
print('Min value',df['Time on App'].min())
# Out:
# Number of unique value 623
# Max value 15.13831679
# Min value 9.273247557

# %%
df['app_bin']=pd.cut(df['Time on App'],bins=[9,10,11,12,13,14,15])
sns.barplot(x=df['app_bin'],y=df['Yealy amount spent'])
# Out:
# <AxesSubplot:xlabel='app_bin', ylabel='Yealy amount spent'>

# %% [markdown]
# # Inference from barplot on Bin Size (Time on App)
# The barplot above shows that as the time on app is increasing the amount spent by customer is decreasing, as we have above already discuss that if "Mobile app usage(usage will rise if time spent on app will rise) is rising in popularity worldwide, which is translating to revenue growth all over the world.". So, company needs to find out why revenue on app is decresing.

# %%
print('Number of unique value',df['Time on Website'].nunique())
print('Max value',df['Time on Website'].max())
print('Min value',df['Time on Website'].min())
# Out:
# Number of unique value 623
# Max value 40.80838798
# Min value 33.75107101

# %%
df['website_bin']=pd.cut(df['Time on Website'],bins=[34,35,36,37,38,39,40])
sns.barplot(x=df['website_bin'],y=df['Yealy amount spent'])
# Out:
# <AxesSubplot:xlabel='website_bin', ylabel='Yealy amount spent'>

# %% [markdown]
# # Inference from barplot on Bin Size (Time on Website)
# We can clearly see that as the time on website is increasing the customer is also spending more. This shows that company website is generating more revenue than the app.

# %%
print('Number of unique value',df['Avg Session length'].nunique())
print('Max value',df['Avg Session length'].max())
print('Min value',df['Avg Session length'].min())
# Out:
# Number of unique value 623
# Max value 35.74441511
# Min value 29.97230008

# %%
df['Avg_Session_length_bin']=pd.cut(df['Avg Session length'],bins=[30,31,32,33,34,35,36])
sns.barplot(x=df['Avg_Session_length_bin'],y=df['Yealy amount spent'])
# Out:
# <AxesSubplot:xlabel='Avg_Session_length_bin', ylabel='Yealy amount spent'>

# %% [markdown]
# # Inference from barplot on Bin Size (Avg Session length)
#
# From above plot we can predict that if customer is spending more time at store the revenue generated by it is decresing, this means that the store facilities is not up to the mark of customer.
#
# Let's see below how it (Avg Session length) affect the order done through app or website.

# %%
sns.barplot(x=df['Avg_Session_length_bin'],y=df['Time on Website'])
# Out:
# <AxesSubplot:xlabel='Avg_Session_length_bin', ylabel='Time on Website'>

# %%
sns.barplot(x=df['Avg_Session_length_bin'],y=df['Time on App'])
# Out:
# <AxesSubplot:xlabel='Avg_Session_length_bin', ylabel='Time on App'>

# %% [markdown]
# # Inference from above 2 barplot
# Well there is not much difference 'Avg Session length' is uniformly distributed among 'Time on App' & 'Time on Website'.

# %%
print('Number of unique value',df['Length of MemberShip'].nunique())
print('Max value',df['Length of MemberShip'].max())
print('Min value',df['Length of MemberShip'].min())
# Out:
# Number of unique value 623
# Max value 6.553916488
# Min value 0.891398412

# %%
df['Length_of_MemberShip_bin']=pd.cut(df['Length of MemberShip'],bins=[1,2,3,4,5,6])
sns.barplot(x=df['Length_of_MemberShip_bin'],y=df['Yealy amount spent'])
# Out:
# <AxesSubplot:xlabel='Length_of_MemberShip_bin', ylabel='Yealy amount spent'>

# %% [markdown]
# # Inference from barplot on Bin Size (Length of MemberShip)
#
# Well 'Length of MemberShip' and 'Yealy amount spent' is showing uniformity. There is no increase in the spending done by customer who are with the company from long time. Company has to see into this matter as well, how to increase there spending although they are loyal customer but company has to find a way like giving them extra discount or pre sale entry to increase there spending with the company.
#
# # Final Inference from Bin Size
#
# As the time on app is increasing the amount spent by customer is decreasing. Time on website is increasing the customer is also spending more. This shows that company website is generating more revenue than the app.
#
# # Final Inference before model building
#
# * Most of the variables are negatively correlated with each other.
# * While visualizing barplot we have seen time has been a very important part of company annual income. How variables are distinguish on time basis on different platform, and how they are influencing the company.
# * Only Time on Website is positively related with all others variables.
# * The dataset is normally distributed.

# %% [markdown]
# # 5. Data Splitting
#
# ## 5.1 Train | Test Split and Scaling
#
# **TASK: Separate the features from the labels into 2 objects, X and y.**
#
# As our objective is to find the variables which are contributing towards the more annual income prediction as well as 'Time on App' or 'Time on Website' which is important. Here, we will take:-
#
# X= [Avg Session length, Time on App, Time on Website, Length of MemberShip]
#
# y= [Yealy amount spent]

# %%
#Separate out the data into X features and Y label.
X= df[df.columns[:4]]
y= df['Yealy amount spent']

# %%
def plot_variable_importance( X , y ):
    tree= DecisionTreeRegressor( random_state = 99 )
    tree.fit( X , y )
    plot_model_var_imp( tree , X , y )
    
def plot_model_var_imp( tree , X , y ):
    imp = pd.DataFrame( 
        tree.feature_importances_  , 
        columns = [ 'Importance' ] , 
        index = X.columns 
    )
    imp = imp.sort_values( [ 'Importance' ] , ascending = True )
    imp[ : 10 ].plot( kind = 'barh' )
    print (tree.score( X , y ))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=101)

# %% [markdown]
# ## 5.2 Feature importance
#
# Selecting the optimal features in the model is important. We will now try to evaluate what the most important variables are for the model to make the prediction.

# %%
plot_variable_importance(X_train, y_train)
# Out:
# 1.0

# %%
tree= DecisionTreeRegressor( random_state = 99 )
tree.fit( X , y )

tree.feature_importances_
# Out:
# array([0.2181372 , 0.22828387, 0.21846063, 0.3351183 ])

# %% [markdown]
# # 6. Modeling
#
# ## 6.1 Model1: Modeling with the linear model and tree based model technique with Standard Scaler.

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)

# %%
X_train_scale = scaler.transform(X_train)

# %%
X_test_scale = scaler.transform(X_test)

# %% [markdown]
# # Fit/Train the Model

# %%
# Choosing the best model among the tree based models
MAE_test_scale_1 = []
MAE_train_scale_1 = []
RMSE_test_scale_1 = []
RMSE_train_scale_1 =[]

MLA= [ LinearRegression(),SVR(),Lasso()]

for i in MLA:
    model1=i.fit(X_train_scale ,y_train)
    # evaluate the model
    test_pred_scale_1 = model1.predict(X_test_scale)
    train_pred_scale_1 = model1.predict(X_train_scale)
    # evaluate predictions
    MAE_test_scale_1.append(mean_absolute_error(y_test,test_pred_scale_1))
    MAE_train_scale_1.append(mean_absolute_error(y_train, train_pred_scale_1))
    RMSE_test_scale_1.append(np.sqrt(mean_squared_error(y_test,test_pred_scale_1)))
    RMSE_train_scale_1.append(np.sqrt(mean_squared_error(y_train,train_pred_scale_1)))

# %%
result_df_scale_1= pd.DataFrame(MAE_test_scale_1, index= ['LinearRegression','Support Vector Machine','lasso regressor'], 
                              columns=['MAE_test']) 
result_df_scale_2= pd.DataFrame(MAE_train_scale_1, index= ['LinearRegression','Support Vector Machine','lasso regressor'],
                              columns=['MAE_train'])
result_df_scale_3= pd.DataFrame(RMSE_test_scale_1, index= ['LinearRegression','Support Vector Machine','lasso regressor'], 
                              columns=['RMSE_test'])
result_df_scale_4= pd.DataFrame(RMSE_train_scale_1, index= ['LinearRegression','Support Vector Machine','lasso regressor'], 
                              columns=['RMSE_train'])

# %% [markdown]
# # Evaluation on the Test & Train Set

# %%
Model_scale = pd.concat([result_df_scale_1, result_df_scale_2, result_df_scale_3, result_df_scale_4], axis=1)

# %%
Model_scale.sort_values(by=['MAE_test'])
# Out:
#                          MAE_test  MAE_train  RMSE_test  RMSE_train
# Support Vector Machine  58.943786  62.685597  72.302936   80.500093
# lasso regressor         60.056694  62.884589  73.460515   80.592627
# LinearRegression        60.387280  62.892734  73.852772   80.565750

# %% [markdown]
# ## 6.2 Model2: Modeling with the linear model and tree based model technique by adjusting outliers & Standard Scaler.
#
# # Modeling by adjusting Outliers

# %%
df2= dataset.copy()

# %%
df2= df2[df2.columns[1:6]]
df2
# Out:
#      Avg Session length  Time on App  Time on Website  Length of MemberShip  \
# 0             32.538350    12.028846        35.850540              3.648854
# 1             34.206718    12.226851        37.246443              1.987536
# 2             31.535240    11.814341        36.610697              3.351191
# 3             32.199577    11.295163        37.425695              5.234337
# 4             33.570137    13.500972        36.856165              3.938603
# ..                  ...          ...              ...                   ...
# 618           31.941434    11.158640        36.846959              3.219605
# 619           33.446133    12.374820        37.592235              4.917733
# 620           32.967749    11.392061        36.916664              2.955718
# 621           33.469949    11.930872        37.744155              4.577850
# 622           33.443393    12.978933        37.311979              3.575459
#
#      Yealy amount spent
# 0            576.098273
# ...

# %% [markdown]
# ## Detecting Outliers

# %%
figure, ax = plt.subplots(3, 2,figsize=(18,12))
sns.boxplot(x=df2['Avg Session length'],data=df2,ax=ax[0,0]);
sns.boxplot(x=df2['Time on App'],data=df2,ax=ax[0,1])
sns.boxplot(x=df2['Time on Website'],data=df2,ax=ax[1,0])
sns.boxplot(x=df2['Length of MemberShip'],data=df2,ax=ax[1,1])
sns.boxplot(x=df2['Yealy amount spent'],data=df2,ax=ax[2,0])
plt.show()

# %%
Q1= df2['Avg Session length'].quantile(0.25)
Q3= df2['Avg Session length'].quantile(0.75)
IQR= Q3-Q1
lower_limit= Q1-(1.5*IQR)
upper_limit= Q3+(1.5*IQR)

# %%
df_outliers = df2[(df2['Avg Session length'] < lower_limit) | (df2['Avg Session length'] > upper_limit)]
df_outliers.head()
# Out:
#      Avg Session length  Time on App  Time on Website  Length of MemberShip  \
# 466           29.972300    10.863173        38.437057              2.715392
# 595           35.744415    10.995713        37.862377              3.068361
#
#      Yealy amount spent
# 466          580.287338
# 595          457.890657

# %%
median = df2['Avg Session length'].median()
df2["Avg Session length"] = np.where((df2["Avg Session length"] >=35), median,df2['Avg Session length'])
df2["Avg Session length"] = np.where((df2["Avg Session length"] <=31.5), median,df2['Avg Session length'])

# %%
'''Visualization'''
import seaborn as sns
sns.boxplot(df2['Avg Session length'])
# Out:
# <AxesSubplot:xlabel='Avg Session length'>

# %%
Q1= df2['Time on App'].quantile(0.25)
Q3= df2['Time on App'].quantile(0.75)
IQR= Q3-Q1
lower_limit= Q1-(1.5*IQR)
upper_limit= Q3+(1.5*IQR)

# %%
df_outliers = df2[(df2['Time on App'] < lower_limit) | (df2['Time on App'] > upper_limit)]
df_outliers.head()
# Out:
#      Avg Session length  Time on App  Time on Website  Length of MemberShip  \
# 16            33.942414    14.840496        36.073746              3.152618
# 149           33.044399    14.766430        35.552051              2.719999
# 400           32.236685     9.273248        35.286466              3.457712
# 403           33.044399    15.138317        35.889082              3.350676
# 487           32.778603     9.332942        36.399571              2.834236
#
#      Yealy amount spent
# 16           483.340718
# 149          496.159467
# 400          572.755469
# 403          467.670090
# 487          451.622325

# %%
median = df2['Time on App'].median()
df2["Time on App"] = np.where((df2["Time on App"] >=14.6), median,df2['Time on App'])
df2["Time on App"] = np.where((df2["Time on App"] <=9.5), median,df2['Time on App'])

# %%
'''Visualization'''
import seaborn as sns
sns.boxplot(df2['Time on App'])
# Out:
# <AxesSubplot:xlabel='Time on App'>

# %%
Q1= df2['Time on Website'].quantile(0.25)
Q3= df2['Time on Website'].quantile(0.75)
IQR= Q3-Q1
lower_limit= Q1-(1.5*IQR)
upper_limit= Q3+(1.5*IQR)

# %%
df_outliers = df2[(df2['Time on Website'] < lower_limit) | (df2['Time on Website'] > upper_limit)]
df_outliers.head()
# Out:
#      Avg Session length  Time on App  Time on Website  Length of MemberShip  \
# 14            34.040366    12.164853        40.006681              4.935085
# 114           32.803528    12.674081        40.808388              4.946204
# 151           34.457991    10.703615        33.883174              1.940848
# 381           32.994988     9.895113        33.751071              5.067124
#
#      Yealy amount spent
# 14           407.694259
# 114          501.665489
# 151          605.829768
# 381          531.562863

# %%
median = df2['Time on Website'].median()
df2["Time on Website"] = np.where((df2["Time on Website"] >=40), median,df2['Time on Website'])
df2["Time on Website"] = np.where((df2["Time on Website"] <=34), median,df2['Time on Website'])

# %%
'''Visualization'''
import seaborn as sns
sns.boxplot(df2['Time on Website'])
# Out:
# <AxesSubplot:xlabel='Time on Website'>

# %%
Q1= df2['Length of MemberShip'].quantile(0.25)
Q3= df2['Length of MemberShip'].quantile(0.75)
IQR= Q3-Q1
lower_limit= Q1-(1.5*IQR)
upper_limit= Q3+(1.5*IQR)

# %%
df_outliers = df2[(df2['Length of MemberShip'] < lower_limit) | (df2['Length of MemberShip'] > upper_limit)]
df_outliers.head()
# Out:
#      Avg Session length  Time on App  Time on Website  Length of MemberShip  \
# 69            32.315148    13.441811        38.293663              6.019829
# 262           33.368670    11.809947        36.634699              6.553916
# 337           33.044399    11.690502        36.627809              6.363211
# 360           34.269842    11.732445        35.613811              0.891398
# 450           33.530223    10.606592        36.074136              6.060564
#
#      Yealy amount spent
# 69           348.639643
# 262          474.822177
# 337          542.996297
# 360          481.564126
# 450          454.917623

# %%
median = df2['Length of MemberShip'].median()
df2["Length of MemberShip"] = np.where((df2["Length of MemberShip"] >=6.0), median,df2['Length of MemberShip'])
df2["Length of MemberShip"] = np.where((df2["Length of MemberShip"] <=1), median,df2['Length of MemberShip'])

# %%
'''Visualization'''
import seaborn as sns
sns.boxplot(df2['Length of MemberShip'])
# Out:
# <AxesSubplot:xlabel='Length of MemberShip'>

# %%
Q1= df2['Yealy amount spent'].quantile(0.25)
Q3= df2['Yealy amount spent'].quantile(0.75)
IQR= Q3-Q1
lower_limit= Q1-(1.5*IQR)
upper_limit= Q3+(1.5*IQR)

# %%
df_outliers = df2[(df2['Yealy amount spent'] < lower_limit) | (df2['Yealy amount spent'] > upper_limit)]
df_outliers.head()
# Out:
#     Avg Session length  Time on App  Time on Website  Length of MemberShip  \
# 6            34.426982     9.997738        38.315963              5.452814
# 9            33.696003    12.488779        36.322443              1.965374
# 20           32.100980    10.850749        37.438323              4.302290
# 28           34.258991    12.894816        37.209936              2.845363
# 44           32.655103    11.452659        38.624902              2.147533
#
#     Yealy amount spent
# 6           272.641578
# 9           775.337626
# 20          256.670000
# 28          734.720524
# 44          765.000000

# %%
median = df2['Yealy amount spent'].median()
df2["Yealy amount spent"] = np.where((df2["Yealy amount spent"] >=675), median,df2['Yealy amount spent'])
df2["Yealy amount spent"] = np.where((df2["Yealy amount spent"] <=320), median,df2['Yealy amount spent'])

# %%
'''Visualization'''
import seaborn as sns
sns.boxplot(df2['Yealy amount spent'])
# Out:
# <AxesSubplot:xlabel='Yealy amount spent'>

# %% [markdown]
# # Train | Test Split

# %%
#Separate out the data into X features and Y label.
X_out= df2[df2.columns[:4]]
y_out= df2['Yealy amount spent']

# %%
X_train_out, X_test_out, y_train_out, y_test_out = train_test_split(X_out, y_out, test_size=0.15, random_state=101)

# %% [markdown]
# # scaling the set

# %%
scaler_out = StandardScaler()

# %%
scaler_out.fit(X_train_out)
# Out:
# StandardScaler()

# %%
X_train_out_scale = scaler.transform(X_train_out)

# %%
X_test_out_scale = scaler.transform(X_test_out)

# %% [markdown]
# # Fit/Train the Model

# %%
# Choosing the best model among the tree based models
MAE_test_scale_out_1 = []
MAE_train_scale_out_1 = []
RMSE_test_scale_out_1 = []
RMSE_train_scale_out_1 =[]

MLA= [ LinearRegression(),SVR(),Lasso()]

for i in MLA:
    model2=i.fit(X_train_out_scale ,y_train_out)
    # evaluate the model
    test_pred_scale_out_1 = model2.predict(X_test_out_scale)
    train_pred_scale_out_1 = model2.predict(X_train_out_scale)
    # evaluate predictions
    MAE_test_scale_out_1.append(mean_absolute_error(y_test_out,test_pred_scale_out_1))
    MAE_train_scale_out_1.append(mean_absolute_error(y_train_out, train_pred_scale_out_1))
    RMSE_test_scale_out_1.append(np.sqrt(mean_squared_error(y_test_out,test_pred_scale_out_1)))
    RMSE_train_scale_out_1.append(np.sqrt(mean_squared_error(y_train_out,train_pred_scale_out_1)))

# %%
# Choosing the best model among the tree based models
MAE_test_scale_1 = []
MAE_train_scale_1 = []
RMSE_test_scale_1 = []
RMSE_train_scale_1 =[]

MLA= [ LinearRegression(),SVR(),Lasso()]

for i in MLA:
    model1=i.fit(X_train_scale ,y_train)
    # evaluate the model
    test_pred_scale_1 = model1.predict(X_test_scale)
    train_pred_scale_1 = model1.predict(X_train_scale)
    # evaluate predictions
    MAE_test_scale_1.append(mean_absolute_error(y_test,test_pred_scale_1))
    MAE_train_scale_1.append(mean_absolute_error(y_train, train_pred_scale_1))
    RMSE_test_scale_1.append(np.sqrt(mean_squared_error(y_test,test_pred_scale_1)))
    RMSE_train_scale_1.append(np.sqrt(mean_squared_error(y_train,train_pred_scale_1)))

# %%
result_df_scale_out_1= pd.DataFrame(MAE_test_scale_out_1, index= ['LinearRegression','Support Vector Machine','lasso regressor'],  
                              columns=['MAE_test']) 
result_df_scale_out_2= pd.DataFrame(MAE_train_scale_out_1, index= ['LinearRegression','Support Vector Machine','lasso regressor'], 
                              columns=['MAE_train'])
result_df_scale_out_3= pd.DataFrame(RMSE_test_scale_out_1,index= ['LinearRegression','Support Vector Machine','lasso regressor'],  
                              columns=['RMSE_test'])
result_df_scale_out_4= pd.DataFrame(RMSE_train_scale_out_1, index= ['LinearRegression','Support Vector Machine','lasso regressor'],  
                              columns=['RMSE_train'])

# %% [markdown]
# # Evaluation on the Test & Train Set

# %%
Model_scale_out = pd.concat([result_df_scale_out_1, result_df_scale_out_2, result_df_scale_out_3, result_df_scale_out_4], axis=1)

# %%
Model_scale_out.sort_values(by=['MAE_test'])
# Out:
#                          MAE_test  MAE_train  RMSE_test  RMSE_train
# Support Vector Machine  56.844544  55.686724  69.860598   69.822742
# lasso regressor         57.998992  56.033917  71.059138   69.771650
# LinearRegression        58.608406  56.011413  71.505865   69.736025

# %% [markdown]
# # final model

# %%
final_model = SVR()

# %%
final_model.fit(X_train_out ,y_train_out)
# Out:
# SVR()

# %% [markdown]
# # Final Hold Out Test Performance for Reporting

# %%
test_pred = final_model.predict(X_test_out)
train_pred = final_model.predict(X_train_out)

# %%
MAE_tst = mean_absolute_error(y_test_out,test_pred)
MSE_tst = mean_squared_error(y_test_out,test_pred)
RMSE_tst = np.sqrt(MSE_tst)

# %%
MAE_tr = mean_absolute_error(y_train_out,train_pred)
MSE_tr = mean_squared_error(y_train_out,train_pred)
RMSE_tr = np.sqrt(MSE_tr)

# %%
print('Test MAE:', MAE_tst)
print('Test RMSE:', RMSE_tst)
print('Train MAE:', MAE_tr)
print('Train RMSE:', RMSE_tr)
# Out:
# Test MAE: 56.89764765563498
# Test RMSE: 69.8631830084666
# Train MAE: 56.303435327960386
# Train RMSE: 70.4838964786417

# %% [markdown]
# # Model saving & Deployment

# %%
from pickle import dump
from pickle import load
from sklearn import metrics

# %%
dump(final_model, open('svm_model.sav','wb'))

# %%
loaded_model=load(open('svm_model.sav','rb'))

# %% [markdown]
# # 9. Conclusion & Recommendation
# * Both models and our data analysis shows that 'Website' generates more sales than 'Mobile App'. So company should focus there budget on website to make it more suitable for the customer.
# * But as we know the exploding popularity of smartphones and tablets has made mobile application development an increasingly popular trend among business owners all over the world. And as above we have also discussed how benefit a mobile app is, we should enhance our user exp. on the Mobile App as well.
# * To increase the company sale from mobile app company should try to make discount chart, if customer order more product from company app than more discount be allowed.
# * And just a website maintenance will be beneficial for regular smooth working of the company.
# * While doing EDA, we have seen'Length of MemberShip' and 'Yealy amount spent' is showing uniformity. There is no increase in the spending done by customer who are with the company from long time. Company has to see into this matter as well, how to increase there spending although they are loyal customer but company has to find a way like giving them extra discount or pre sale entry to increase there spending with the company.
# * Lastly, **So as Time on Website is a much more significant factor than Time on App, the company has a choice: they could either focus all the attention into the Website as that is what is bringing the most money in, or they could focus on the App as it is performing so poorly! I would recommend company to spent more on website and make it more smooth but also increase the user exp. on mobile app as well.**
